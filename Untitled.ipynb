# %%
import matplotlib.pyplot as plt
import numpy as np
from sklearn import datasets, linear_model
from sklearn.metrics import mean_squared_error, r2_score

# Carregando o dataset de diabetes
diabetes = datasets.load_diabetes()

# Usando apenas uma feature
diabetes_X = diabetes.data[:, np.newaxis, 2]

# %%
#Importando o módulo responsável por separar os arrays em dados de treino e teste
from sklearn.model_selection import train_test_split
#Separando em 4 arrays e setando 70% de todos os dados para treino
diabetes_X_train, diabetes_X_test, diabetes_y_train, diabetes_y_test = train_test_split(diabetes_X, diabetes.target, train_size=0.4)
# Out:
# c:\users\hp1\appdata\local\programs\python\python37-32\lib\site-packages\sklearn\model_selection\_split.py:2069: FutureWarning: From version 0.21, test_size will always complement train_size unless both are specified.
#   FutureWarning)

# %%
# Plotando os dados de teste
plt.plot(diabetes_X_train, diabetes_y_train, 'o');
plt.xlabel('X')
plt.ylabel('Y')
plt.show()

# %%
# Criando um objeto de regressão linear
regr = linear_model.LinearRegression()

# Treinando o modelo com os dados de treino
regr.fit(diabetes_X_train, diabetes_y_train)

# Fazendo predição com os dados de teste
diabetes_y_pred = regr.predict(diabetes_X_test)

# %%
# Plotando os resultados da predição
plt.scatter(diabetes_X_test, diabetes_y_test,  color='black')
plt.plot(diabetes_X_test, diabetes_y_pred, color='blue', linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
# Erro médio quadrático
print("Erro médio quadrático: %.2f"
      % mean_squared_error(diabetes_y_test, diabetes_y_pred))
# Score do erro médio quadrático: quanto mais perto do 1, melhor é a predição
print('Score do erro médio quadrático: %.2f' % r2_score(diabetes_y_test, diabetes_y_pred))
# Out:
# Erro médio quadrático: 3488.18
# Score do erro médio quadrático: 0.38
