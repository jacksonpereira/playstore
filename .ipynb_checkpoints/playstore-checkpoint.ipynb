# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
from sklearn.cluster import KMeans
df = pd.read_csv('googleplaystore_user_reviews.csv')
df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2       NaN                 NaN                     NaN
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000

# %%
#Atribuir as medias às variáveis aleatórias quantitativas que possuem o NaN
Sentiment_Polarity = df['Sentiment_Polarity'].copy()
Sentiment_Subjectivity = df['Sentiment_Subjectivity'].copy()
Sentiment_Polarity[Sentiment_Polarity.isna() == True] = df['Sentiment_Polarity'].mean()
Sentiment_Subjectivity[Sentiment_Subjectivity.isna() == True] = df['Sentiment_Subjectivity'].mean()
df['Sentiment_Polarity']= Sentiment_Polarity
df['Sentiment_Subjectivity']= Sentiment_Subjectivity
#df[df['Sentiment_Subjectivity'].isna() == True] = df['Sentiment_Subjectivity'].mean()
#newDF = pd.DataFrame({'App': df['App'], 'Translated_Review' : df['Translated_Review'], 'Sentiment' : df['Sentiment'], })
df
# Out:
#                                App  \
# 0            10 Best Foods for You
# 1            10 Best Foods for You
# 2            10 Best Foods for You
# 3            10 Best Foods for You
# 4            10 Best Foods for You
# 5            10 Best Foods for You
# 6            10 Best Foods for You
# 7            10 Best Foods for You
# 8            10 Best Foods for You
# 9            10 Best Foods for You
# 10           10 Best Foods for You
# 11           10 Best Foods for You
# 12           10 Best Foods for You
# 13           10 Best Foods for You
# 14           10 Best Foods for You
# 15           10 Best Foods for You
# 16           10 Best Foods for You
# 17           10 Best Foods for You
# 18           10 Best Foods for You
# 19           10 Best Foods for You
# 20           10 Best Foods for You
# 21           10 Best Foods for You
# 22           10 Best Foods for You
# 23           10 Best Foods for You
# 24           10 Best Foods for You
# 25           10 Best Foods for You
# 26           10 Best Foods for You
# 27           10 Best Foods for You
# 28           10 Best Foods for You
# 29           10 Best Foods for You
# ...                            ...
# 64265  Houzz Interior Design Ideas
# 64266  Houzz Interior Design Ideas
# 64267  Houzz Interior Design Ideas
# 64268  Houzz Interior Design Ideas
# 64269  Houzz Interior Design Ideas
# 64270  Houzz Interior Design Ideas
# 64271  Houzz Interior Design Ideas
# 64272  Houzz Interior Design Ideas
# 64273  Houzz Interior Design Ideas
# 64274  Houzz Interior Design Ideas
# 64275  Houzz Interior Design Ideas
# 64276  Houzz Interior Design Ideas
# 64277  Houzz Interior Design Ideas
# 64278  Houzz Interior Design Ideas
# 64279  Houzz Interior Design Ideas
# 64280  Houzz Interior Design Ideas
# 64281  Houzz Interior Design Ideas
# 64282  Houzz Interior Design Ideas
# 64283  Houzz Interior Design Ideas
# 64284  Houzz Interior Design Ideas
# 64285  Houzz Interior Design Ideas
# 64286  Houzz Interior Design Ideas
# 64287  Houzz Interior Design Ideas
# 64288  Houzz Interior Design Ideas
# 64289  Houzz Interior Design Ideas
# 64290  Houzz Interior Design Ideas
# 64291  Houzz Interior Design Ideas
# 64292  Houzz Interior Design Ideas
# 64293  Houzz Interior Design Ideas
# 64294  Houzz Interior Design Ideas
#
#                                        Translated_Review Sentiment  \
# 0      I like eat delicious food. That's I'm cooking ...  Positive
# 1        This help eating healthy exercise regular basis  Positive
# 2                                                    NaN       NaN
# 3             Works great especially going grocery store  Positive
# 4                                           Best idea us  Positive
# 5                                               Best way  Positive
# 6                                                Amazing  Positive
# 7                                                    NaN       NaN
# 8                                   Looking forward app,   Neutral
# 9                  It helpful site ! It help foods get !   Neutral
# 10                                             good you.  Positive
# 11     Useful information The amount spelling errors ...  Positive
# 12     Thank you! Great app!! Add arthritis, eyes, im...  Positive
# 13     Greatest ever Completely awesome maintain heal...  Positive
# 14     Good health...... Good health first priority.....  Positive
# 15                                                   NaN       NaN
# 16     Health It's important world either life . thin...  Positive
# 17     Mrs sunita bhati I thankful developers,to make...  Positive
# 18     Very Useful in diabetes age 30. I need control...  Positive
# 19                                    One greatest apps.  Positive
# 20                                             good nice  Positive
# 21                                 Healthy Really helped  Positive
# 22                                            God health   Neutral
# 23     HEALTH SHOULD ALWAYS BE TOP PRIORITY. !!. ON M...  Positive
# 24                                 An excellent A useful  Positive
# 25                     I found lot wealth form health...   Neutral
# 26                            Because I found important.  Positive
# 27                                        Healthy Eating  Positive
# 28                                 Very good Simply good  Positive
# 29                                           On test....   Neutral
# ...                                                  ...       ...
# 64265                                                NaN       NaN
# 64266                                                NaN       NaN
# 64267                                                NaN       NaN
# 64268                                                NaN       NaN
# 64269                                                NaN       NaN
# 64270                                                NaN       NaN
# 64271                                                NaN       NaN
# 64272                                                NaN       NaN
# 64273                                                NaN       NaN
# 64274                                                NaN       NaN
# 64275                                                NaN       NaN
# 64276                                                NaN       NaN
# 64277                                                NaN       NaN
# 64278                                                NaN       NaN
# 64279                                                NaN       NaN
# 64280                                                NaN       NaN
# 64281                                                NaN       NaN
# 64282                                                NaN       NaN
# 64283                                                NaN       NaN
# 64284                                                NaN       NaN
# 64285                                                NaN       NaN
# 64286                                                NaN       NaN
# 64287                                                NaN       NaN
# 64288                                                NaN       NaN
# 64289                                                NaN       NaN
# 64290                                                NaN       NaN
# 64291                                                NaN       NaN
# 64292                                                NaN       NaN
# 64293                                                NaN       NaN
# 64294                                                NaN       NaN
#
#        Sentiment_Polarity  Sentiment_Subjectivity
# 0                1.000000                0.533333
# 1                0.250000                0.288462
# 2                0.182146                0.492704
# 3                0.400000                0.875000
# 4                1.000000                0.300000
# 5                1.000000                0.300000
# 6                0.600000                0.900000
# 7                0.182146                0.492704
# 8                0.000000                0.000000
# 9                0.000000                0.000000
# 10               0.700000                0.600000
# 11               0.200000                0.100000
# 12               0.750000                0.875000
# 13               0.992188                0.866667
# 14               0.550000                0.511111
# 15               0.182146                0.492704
# 16               0.450000                1.000000
# 17               0.600000                0.666667
# 18               0.295000                0.100000
# 19               1.000000                1.000000
# 20               0.650000                0.800000
# 21               0.350000                0.350000
# 22               0.000000                0.000000
# 23               0.781250                0.500000
# 24               0.650000                0.500000
# 25               0.000000                0.000000
# 26               0.400000                1.000000
# 27               0.500000                0.500000
# 28               0.805000                0.690000
# 29               0.000000                0.000000
# ...                   ...                     ...
# 64265            0.182146                0.492704
# 64266            0.182146                0.492704
# 64267            0.182146                0.492704
# 64268            0.182146                0.492704
# 64269            0.182146                0.492704
# 64270            0.182146                0.492704
# 64271            0.182146                0.492704
# 64272            0.182146                0.492704
# 64273            0.182146                0.492704
# 64274            0.182146                0.492704
# 64275            0.182146                0.492704
# 64276            0.182146                0.492704
# 64277            0.182146                0.492704
# 64278            0.182146                0.492704
# 64279            0.182146                0.492704
# 64280            0.182146                0.492704
# 64281            0.182146                0.492704
# 64282            0.182146                0.492704
# 64283            0.182146                0.492704
# 64284            0.182146                0.492704
# 64285            0.182146                0.492704
# 64286            0.182146                0.492704
# 64287            0.182146                0.492704
# 64288            0.182146                0.492704
# 64289            0.182146                0.492704
# 64290            0.182146                0.492704
# 64291            0.182146                0.492704
# 64292            0.182146                0.492704
# 64293            0.182146                0.492704
# 64294            0.182146                0.492704
#
# [64295 rows x 5 columns]

# %%
#Retirar os valores duplicados
df = df[df.duplicated() == False]
df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You                                                NaN
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive            1.000000                0.533333
# 1  Positive            0.250000                0.288462
# 2       NaN            0.182146                0.492704
# 3  Positive            0.400000                0.875000
# 4  Positive            1.000000                0.300000

# %%
#Tirar os valores NaN
df = df[df['App'].isna() == False]
df = df[df['Translated_Review'].isna() == False]
df = df[df['Sentiment'].isna() == False]
df.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 3  10 Best Foods for You         Works great especially going grocery store
# 4  10 Best Foods for You                                       Best idea us
# 5  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 3  Positive                0.40                0.875000
# 4  Positive                1.00                0.300000
# 5  Positive                1.00                0.300000

# %%
df.to_csv('googleplaystore_user_reviews_cleaned.csv', sep=',', index=False)
t = pd.read_csv('googleplaystore_user_reviews_cleaned.csv')
t.head()
# Out:
#                      App                                  Translated_Review  \
# 0  10 Best Foods for You  I like eat delicious food. That's I'm cooking ...
# 1  10 Best Foods for You    This help eating healthy exercise regular basis
# 2  10 Best Foods for You         Works great especially going grocery store
# 3  10 Best Foods for You                                       Best idea us
# 4  10 Best Foods for You                                           Best way
#
#   Sentiment  Sentiment_Polarity  Sentiment_Subjectivity
# 0  Positive                1.00                0.533333
# 1  Positive                0.25                0.288462
# 2  Positive                0.40                0.875000
# 3  Positive                1.00                0.300000
# 4  Positive                1.00                0.300000

# %%
plt.plot(df['Sentiment_Polarity'], df['Sentiment_Subjectivity'], 'o');
plt.xlabel('Sentiment_Polarity')
plt.ylabel('Sentiment_Subjectivity')
# Out:
# Text(0, 0.5, 'Sentiment_Subjectivity')

# %%
arr = np.array(df.loc[0:, 'Sentiment_Polarity':'Sentiment_Subjectivity'])
arr
# Out:
# array([[ 1.        ,  0.53333333],
#        [ 0.25      ,  0.28846154],
#        [ 0.4       ,  0.875     ],
#        ...,
#        [-0.2875    ,  0.25      ],
#        [ 0.8       ,  1.        ],
#        [-0.31666667,  0.4       ]])

# %%
cluster = KMeans(n_clusters=3)
cluster
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
cluster.fit(arr)
# Out:
# KMeans(algorithm='auto', copy_x=True, init='k-means++', max_iter=300,
#     n_clusters=3, n_init=10, n_jobs=None, precompute_distances='auto',
#     random_state=None, tol=0.0001, verbose=0)

# %%
print(cluster.cluster_centers_)
# Out:
# [[ 0.52749744  0.6611088 ]
#  [ 0.0750467   0.26955655]
#  [-0.26540158  0.63826479]]

# %%
print(cluster.labels_)
# Out:
# [0 1 0 ... 1 0 2]

# %%
plt.scatter(arr[:,0], arr[:,1], c=cluster.labels_, cmap='rainbow')
plt.scatter(cluster.cluster_centers_[:,0], cluster.cluster_centers_[:, 1], color='black')

# %%
#Descobrindo a pontuação da classificação
cluster.score(arr)
# Out:
# -2155.4992548960527

# %%
#Saber a qual conjunto o array pertence
resultado = cluster.predict([[1, 0.533333]])

if resultado[0] == 0:
    print('Bom')
elif resultado[0] == 1:
    print('Médio')
elif resultado[0] == 2:
    print('Médio 2')
    elif resultado[0] == 2:
    print('Médio 2')
# Out:
# Bom
